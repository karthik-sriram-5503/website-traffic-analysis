# %% [markdown]
# <a href="https://colab.research.google.com/github/karthik-sriram-5503/website-traffic-analysis/blob/main/visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #WEBSITE TRAFFIC ANALYSIS

# %%
#importing the dependency
import pandas as pd

# %%
#importing the dataset
path="/content/daily-website-visitors.csv"
whole_dataset = pd.read_csv(path,
                            index_col='Date',
                            thousands=',')

# %%
whole_dataset
# Out:
#             Row        Day  Day.Of.Week  Page.Loads  Unique.Visits  \
# Date
# 9/14/2014     1     Sunday            1        2146           1582
# 9/15/2014     2     Monday            2        3621           2528
# 9/16/2014     3    Tuesday            3        3698           2630
# 9/17/2014     4  Wednesday            4        3667           2614
# 9/18/2014     5   Thursday            5        3316           2366
# ...         ...        ...          ...         ...            ...
# 8/15/2020  2163   Saturday            7        2221           1696
# 8/16/2020  2164     Sunday            1        2724           2037
# 8/17/2020  2165     Monday            2        3456           2638
# 8/18/2020  2166    Tuesday            3        3581           2683
# 8/19/2020  2167  Wednesday            4        2064           1564
#
#            First.Time.Visits  Returning.Visits
# Date
# 9/14/2014               1430               152
# 9/15/2014               2297               231
# ...

# %% [markdown]
# converting date to proper format

# %%
whole_dataset.index = pd.to_datetime(whole_dataset.index)
whole_dataset
# Out:
#              Row        Day  Day.Of.Week  Page.Loads  Unique.Visits  \
# Date
# 2014-09-14     1     Sunday            1        2146           1582
# 2014-09-15     2     Monday            2        3621           2528
# 2014-09-16     3    Tuesday            3        3698           2630
# 2014-09-17     4  Wednesday            4        3667           2614
# 2014-09-18     5   Thursday            5        3316           2366
# ...          ...        ...          ...         ...            ...
# 2020-08-15  2163   Saturday            7        2221           1696
# 2020-08-16  2164     Sunday            1        2724           2037
# 2020-08-17  2165     Monday            2        3456           2638
# 2020-08-18  2166    Tuesday            3        3581           2683
# 2020-08-19  2167  Wednesday            4        2064           1564
#
#             First.Time.Visits  Returning.Visits
# Date
# 2014-09-14               1430               152
# ...

# %%
whole_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2167 entries, 2014-09-14 to 2020-08-19
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Row                2167 non-null   int64
#  1   Day                2167 non-null   object
#  2   Day.Of.Week        2167 non-null   int64
#  3   Page.Loads         2167 non-null   int64
#  4   Unique.Visits      2167 non-null   int64
#  5   First.Time.Visits  2167 non-null   int64
#  6   Returning.Visits   2167 non-null   int64
# dtypes: int64(6), object(1)
# memory usage: 135.4+ KB

# %%
whole_dataset.describe()
# Out:
#                Row  Day.Of.Week   Page.Loads  Unique.Visits  \
# count  2167.000000  2167.000000  2167.000000    2167.000000
# mean   1084.000000     3.997231  4116.989386    2943.646516
# std     625.703338     2.000229  1350.977843     977.886472
# min       1.000000     1.000000  1002.000000     667.000000
# 25%     542.500000     2.000000  3114.500000    2226.000000
# 50%    1084.000000     4.000000  4106.000000    2914.000000
# 75%    1625.500000     6.000000  5020.500000    3667.500000
# max    2167.000000     7.000000  7984.000000    5541.000000
#
#        First.Time.Visits  Returning.Visits
# count        2167.000000       2167.000000
# mean         2431.824181        511.822335
# std           828.704688        168.736370
# min           522.000000        133.000000
# 25%          1830.000000        388.500000
# 50%          2400.000000        509.000000
# 75%          3038.000000        626.500000
# max          4616.000000       1036.000000

# %% [markdown]
# checking for NaN values

# %%
whole_dataset.isna().sum()
# Out:
# Row                  0
# Day                  0
# Day.Of.Week          0
# Page.Loads           0
# Unique.Visits        0
# First.Time.Visits    0
# Returning.Visits     0
# dtype: int64

# %% [markdown]
# checking for duplicate values

# %%
whole_dataset.duplicated().sum()
# Out:
# 0

# %%
whole_dataset.plot(figsize=(14,7))
# Out:
# <Axes: xlabel='Date'>

# %%
import numpy as np
from scipy.stats import norm

# %%
mean = whole_dataset['Page.Loads'].mean()
print( "mean loads per day:", mean)
fig, ax1 = plt.subplots()
whole_dataset['Page.Loads'].plot.hist(ax = ax1, label='Page.Loads')

plt.plot([mean,mean], [0, 480], label='mean')
n = 1
px = np.linspace(1, 8000, 50)
py = np.zeros(50)
std = whole_dataset['Page.Loads'].std()
print( "std deviation of loads per day:", std)
for i in range(0, 50):
    x = (px[i]-mean)/std
    p = norm.pdf(x)
    py[i] = 1000*p
plt.plot(px, py, label='normal', color='red')
plt.legend()
plt.show()
# Out:
# mean loads per day: 4116.9893862482695
# std deviation of loads per day: 1350.9778426999621

# %%
dict_format = whole_dataset.to_dict()

# %%
dict_format

# %%
import numpy as np

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# Create a DataFrame
df = pd.DataFrame(dict_format)

# Create a box plot for each column
plt.figure(figsize=(10, 6))
sns.boxplot(data=df)
plt.title('BOX PLOT ' )
plt.show()

# %%
Q1 = np.percentile(whole_dataset , 25)
Q3 = np.percentile(whole_dataset , 75)
# method 2.
Q1,Q3 = np.percentile(whole_dataset , [25,75])
IQR = Q3 - Q1
ul = Q3+1.5*IQR
ll = Q1-1.5*IQR
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-413009d1240f> in <cell line: 1>()
# ----> 1 Q1 = np.percentile(whole_dataset , 25)
#       2 Q3 = np.percentile(whole_dataset , 75)
#       3 # method 2.
#       4 Q1,Q3 = np.percentile(whole_dataset , [25,75])
#       5 IQR = Q3 - Q1
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/overrides.py in percentile(*args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py in percentile(a, q, axis, out, overwrite_input, method, keepdims, interpolation)
#    4164     if not _quantile_is_valid(q):
#    4165         raise ValueError("Percentiles must be in the range [0, 100]")
# -> 4166     return _quantile_unchecked(
#    4167         a, q, axis, out, overwrite_input, method, keepdims)
#    4168
#
# ...

# %%
outliers = whole_datase[(whole_dataset > ul) | (whole_dataset < ll)]
outliers

# %%
fig = plt.figure(figsize=(6,5))
hypo = np.random.randint(20, 81, size=500)
plt.boxplot([whole_dataset, hypo], widths=0.5)
plt.xticks([1,2],['Our data', 'Hypothetical data'])
plt.ylabel('Grade')
plt.title('Box plot of midterm grade')
plt.show()
